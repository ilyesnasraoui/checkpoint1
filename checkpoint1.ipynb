# %% [markdown]
# # data

# %% [markdown]
# ## ghj

# %% [markdown]
# srdfhfghljklmlfkdshfqghgfghjliufjgvbnmlkhgukttljgjcmogig

# %%
print("gfds")
# Out:
# gfds

# %% [markdown]
# ![image.png](attachment:image.png)
